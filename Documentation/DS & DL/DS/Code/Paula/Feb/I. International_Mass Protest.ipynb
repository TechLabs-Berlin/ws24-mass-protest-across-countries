# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
# %cd drive/MyDrive/Colab_Notebooks/TechLabs/03_Statistics\ and\ Data\ Visualization/Part\ C\ -\ Multivariate\ Data
# Out:
# /content/drive/MyDrive/Colab_Notebooks/TechLabs/03_Statistics and Data Visualization/Part C - Multivariate Data

# %% [markdown]
# * Take notes here.
#     * And here.
# * ...
# * ...

# %% [markdown]
# <hr style="border:2px solid gray"> </hr>
#
# ## How to select dataframe subsets from multivariate data

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100) # Show all columns when looking at dataframe

# %%
df = pd.read_csv("data/first_data_MP.csv", on_bad_lines='warn')

# %%
df.head()
# Out:
#           id country  ccode  year         region  protest  protestnumber  \
# 0  201990001  Canada     20  1990  North America        1              1
# 1  201990002  Canada     20  1990  North America        1              2
# 2  201990003  Canada     20  1990  North America        1              3
# 3  201990004  Canada     20  1990  North America        1              4
# 4  201990005  Canada     20  1990  North America        1              5
#
#    startday  startmonth  startyear  endday  endmonth  endyear  \
# 0      15.0         1.0     1990.0    15.0       1.0   1990.0
# 1      25.0         6.0     1990.0    25.0       6.0   1990.0
# 2       1.0         7.0     1990.0     1.0       7.0   1990.0
# 3      12.0         7.0     1990.0     6.0       9.0   1990.0
# 4      14.0         8.0     1990.0    15.0       8.0   1990.0
#
#    protesterviolence          location participants_category participants  \
# 0                0.0          national                   NaN        1000s
# ...

# %% [markdown]
# ### Keep only body measures columns, so only columns with "BMX" in the name

# %%
# get columns names
col_names = df.columns
col_names
# Out:
# Index(['id', 'country', 'ccode', 'year', 'region', 'protest', 'protestnumber',
#        'startday', 'startmonth', 'startyear', 'endday', 'endmonth', 'endyear',
#        'protesterviolence', 'location', 'participants_category',
#        'participants', 'protesteridentity', 'protesterdemand1',
#        'protesterdemand2', 'protesterdemand3', 'protesterdemand4',
#        'stateresponse1', 'stateresponse2', 'stateresponse3', 'stateresponse4',
#        'stateresponse5', 'stateresponse6', 'stateresponse7', 'sources',
#        'notes'],
#       dtype='object')

# %%
rows = df.shape[0]
columns = df.shape[1]
print("Our survey Data has {} rows ad {} columns.".format(rows, columns))
# Out:
# Our survey Data has 17145 rows ad 31 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17145 entries, 0 to 17144
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     17145 non-null  int64
#  1   country                17145 non-null  object
#  2   ccode                  17145 non-null  int64
#  3   year                   17145 non-null  int64
#  4   region                 17145 non-null  object
#  5   protest                17145 non-null  int64
#  6   protestnumber          17145 non-null  int64
#  7   startday               15239 non-null  float64
#  8   startmonth             15239 non-null  float64
#  9   startyear              15239 non-null  float64
#  10  endday                 15239 non-null  float64
#  11  endmonth               15239 non-null  float64
#  12  endyear                15239 non-null  float64
#  13  protesterviolence      15758 non-null  float64
# ...

# %%
df['country'].value_counts()
# Out:
# United Kingdom           578
# France                   547
# Ireland                  438
# Germany                  364
# Kenya                    353
#                         ...
# Germany East              11
# South Sudan               10
# Czechoslovakia             6
# Serbia and Montenegro      5
# Germany West               2
# Name: country, Length: 166, dtype: int64

# %%
countries = df['country'].value_counts(sort = False)
print(countries.dtype)
print(countries)
# Out:
# int64
# Canada                 60
# Cuba                  122
# Haiti                 124
# Dominican Republic     83
# Jamaica                45
#                      ...
# Singapore              39
# Philippines            72
# Indonesia             153
# Timor Leste            22
# Papua New Guinea       50
# Name: country, Length: 166, dtype: int64

# %%
# looking at the first row
df.loc[0]

# %%
# all of canada -> counting rows
canada = df.loc[:59]
print(canada )

# %% [markdown]
# Questions we could ask:
# filtering after countries, years, region, participants

# %%
# filtering countries for example Canada & year
Canada =(df['country'] == 'Canada') & (df['year'] == 2000)
df[Canada]
# Out:
#            id country  ccode  year         region  protest  protestnumber  \
# 20  202000001  Canada     20  2000  North America        1              1
# 21  202000002  Canada     20  2000  North America        1              2
# 22  202000003  Canada     20  2000  North America        1              3
# 23  202000004  Canada     20  2000  North America        1              4
#
#     startday  startmonth  startyear  endday  endmonth  endyear  \
# 20      22.0         2.0     2000.0    23.0       2.0   2000.0
# 21      26.0         2.0     2000.0    26.0       2.0   2000.0
# 22       9.0         5.0     2000.0     9.0       5.0   2000.0
# 23      16.0         6.0     2000.0    16.0       6.0   2000.0
#
#     protesterviolence                 location participants_category  \
# 20                1.0      Quebec City, Quebec                   NaN
# 21                0.0  Saskatoon, Saskatchewan                   NaN
# ...
