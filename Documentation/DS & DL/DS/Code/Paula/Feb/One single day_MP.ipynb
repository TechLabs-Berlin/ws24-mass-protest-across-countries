# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
# %cd drive/MyDrive/Colab_Notebooks/TechLabs/03_Statistics\ and\ Data\ Visualization/Part\ C\ -\ Multivariate\ Data
# Out:
# /content/drive/MyDrive/Colab_Notebooks/TechLabs/03_Statistics and Data Visualization/Part C - Multivariate Data

# %% [markdown]
# **Seeing one day i downloaded as csv to se how i can sort all days !!**

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100) # Show all columns when looking at dataframe

# %%
df = pd.read_csv("data/versammlungsbehörde_berlin_MP.csv", on_bad_lines='warn')
# Out:
# Skipping line 4: expected 1 fields, saw 2
# Skipping line 7: expected 1 fields, saw 4
# Skipping line 8: expected 1 fields, saw 7
# Skipping line 9: expected 1 fields, saw 2
# Skipping line 12: expected 1 fields, saw 2
# Skipping line 13: expected 1 fields, saw 2
# Skipping line 15: expected 1 fields, saw 5
# Skipping line 19: expected 1 fields, saw 4
# Skipping line 21: expected 1 fields, saw 2
# Skipping line 25: expected 1 fields, saw 7
# Skipping line 26: expected 1 fields, saw 2
# Skipping line 29: expected 1 fields, saw 3
# Skipping line 30: expected 1 fields, saw 6
# Skipping line 31: expected 1 fields, saw 2
# Skipping line 32: expected 1 fields, saw 5
# Skipping line 33: expected 1 fields, saw 5
# Skipping line 34: expected 1 fields, saw 3
# Skipping line 37: expected 1 fields, saw 2
# Skipping line 38: expected 1 fields, saw 2
# Skipping line 40: expected 1 fields, saw 7
# Skipping line 41: expected 1 fields, saw 2
# Skipping line 43: expected 1 fields, saw 3
# ...

# %%
df.head(25)
# Out:
#    id;datum;von;bis;thema;plz;strasse_nr;aufzugsstrecke;lfdnr
# 0   3;21.02.2024;00:00;20:00;"Day X Free Assange f...
# 1   6;21.02.2024;00:00;23:59;"DAUERMAHNWACHE VOR D...
# 2   12;21.02.2024;08:00;14:00;"Streik ISS Communic...
# 3   15;21.02.2024;10:00;18:00;"Hinrichtungswelle i...
# 4   27;21.02.2024;11:30;19:00;"FREIHEIT FÜR JULIAN...
# 5   30;21.02.2024;12:00;13:30;"Mahnwache: Tiertran...
# 6   39;21.02.2024;16:00;19:00;"Umgestaltung des He...
# 7   45;21.02.2024;17:30;20:30;"Animal Rights Squar...
# 8   48;21.02.2024;18:00;19:30;"Solidarität mit Pal...
# 9   51;21.02.2024;18:00;20:00;"Stoppt die AfD und ...
# 10  57;22.02.2024;00:00;23:59;"DAUERMAHNWACHE VOR ...
# 11  63;22.02.2024;07:45;09:15;"Kinder haben Rechte...
# 12  66;22.02.2024;08:30;09:30;"Aufklärung rechter ...
# 13  69;22.02.2024;10:00;18:00;"Hinrichtungswelle i...
# 14  78;22.02.2024;15:00;19:00;"Familiennachzug - J...
# 15  81;22.02.2024;16:00;17:00;"Erhalt des Thaimark...
# ...

# %% [markdown]
# **general info:**

# %%
# get columns names
col_names = df.columns
col_names
# Out:
# Index(['id;datum;von;bis;thema;plz;strasse_nr;aufzugsstrecke;lfdnr'], dtype='object')

# %%
rows = df.shape[0]
columns = df.shape[1]
print("Our survey Data has {} rows ad {} columns.".format(rows, columns))
# Out:
# Our survey Data has 819 rows ad 1 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 819 entries, 0 to 818
# Data columns (total 1 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   id;datum;von;bis;thema;plz;strasse_nr;aufzugsstrecke;lfdnr  819 non-null    object
# dtypes: object(1)
# memory usage: 6.5+ KB

# %% [markdown]
# ### those ??... need to be seperated into 9 single columns or more

# %% [markdown]
# Link:
# > https://www.delftstack.com/howto/python-pandas/split-column-in-python-pandas/
# > > df.Series.str.split(pat=None, n=-1, expand=False)
#
# Problem:
# > AttributeError: 'function' object has no attribute 'str'
# > > need to [the column name] & lose '.' before as 'first' is a function in dataframe
# > > > function I finally used:
# df['name of column'].str.split(pat=" ", expand=True)

# %%
df = df['id;datum;von;bis;thema;plz;strasse_nr;aufzugsstrecke;lfdnr'].str.split(pat=";", expand=True)

# %%
# changing column names
df.columns = ['id', 'date', 'time_start', 'time_finish', 'topic', 'zip_start', 'street_start', 'passway or other', 'zip_end', 'street_end', '9', '10']
print(df)
# Out:
#        id        date time_start time_finish  \
# 0       3  21.02.2024      00:00       20:00
# 1       6  21.02.2024      00:00       23:59
# 2      12  21.02.2024      08:00       14:00
# 3      15  21.02.2024      10:00       18:00
# 4      27  21.02.2024      11:30       19:00
# ..    ...         ...        ...         ...
# 814  5436  01.05.2029      13:00       19:00
# 815  5439  18.09.2029      14:00       17:00
# 816  5442  01.05.2030      13:00       19:00
# 817  5445  01.05.2031      13:00       19:00
# 818  5448  01.05.2032      13:00       19:00
#
#                                                  topic zip_start  \
# 0    "Day X Free Assange für Meinungs- und Pressefr...     10117
# 1    "DAUERMAHNWACHE VOR DEM BMJ IN BERLIN. HUNGERS...   HE&#304
# 2                           "Streik ISS Communication"     10713
# 3    "Hinrichtungswelle im Iran stoppen/ Anhaltende...     10557
# 4    "FREIHEIT FÜR JULIAN ASSANGE! Presse- und Mein...
# ...

# %%
df.head(25)
# Out:
#      id        date time_start time_finish  \
# 0     3  21.02.2024      00:00       20:00
# 1     6  21.02.2024      00:00       23:59
# 2    12  21.02.2024      08:00       14:00
# 3    15  21.02.2024      10:00       18:00
# 4    27  21.02.2024      11:30       19:00
# 5    30  21.02.2024      12:00       13:30
# 6    39  21.02.2024      16:00       19:00
# 7    45  21.02.2024      17:30       20:30
# 8    48  21.02.2024      18:00       19:30
# 9    51  21.02.2024      18:00       20:00
# 10   57  22.02.2024      00:00       23:59
# 11   63  22.02.2024      07:45       09:15
# 12   66  22.02.2024      08:30       09:30
# 13   69  22.02.2024      10:00       18:00
# 14   78  22.02.2024      15:00       19:00
# 15   81  22.02.2024      16:00       17:00
# 16  102  22.02.2024      18:00       20:00
# 17  105  23.02.2024      00:00       23:59
# 18  114  23.02.2024      10:00       18:00
# 19  123  23.02.2024      11:00       16:00
# 20  135  23.02.2024      17:00       19:30
# ...

# %%
df.sort_values('date', ascending=True )
# Out:
#        id        date time_start time_finish  \
# 76    441  01.03.2024      08:30       09:45
# 82    468  01.03.2024      17:30       19:00
# 81    465  01.03.2024      15:00       16:00
# 77    447  01.03.2024      10:00       12:30
# 79    456  01.03.2024      11:30       14:00
# ..    ...         ...        ...         ...
# 415  2706  31.05.2024      18:30       20:00
# 553  3612  31.07.2024      16:00       19:00
# 593  3951  31.08.2024      17:00       19:00
# 705  4704  31.10.2024      16:00       19:00
# 704  4695  31.10.2024      08:30       09:30
#
#                                                  topic zip_start  \
# 76   "Zubringer-Fahrraddemo: Alle gemeinsam zum Kli...
# 82   "Wir stehen an eurer Seite - Mahnwache zum Sch...     10999
# 81   "Mahnwache gegen rechtsextremistische Tendenze...     10178
# 77        "Vergütungserhöhung für Verfahrensbeistände"
# 79   "Stoppt den staatlich geförderten und andauern...     10117
# ...

# %%
df.sort_values('10', ascending=True )
# Out:
#        id        date time_start time_finish  \
# 60    342  27.02.2024      00:00       23:59
# 65    372  28.02.2024      00:00       23:59
# 72    408  29.02.2024      00:00       23:59
# 10     57  22.02.2024      00:00       23:59
# 1       6  21.02.2024      00:00       23:59
# ..    ...         ...        ...         ...
# 814  5436  01.05.2029      13:00       19:00
# 815  5439  18.09.2029      14:00       17:00
# 816  5442  01.05.2030      13:00       19:00
# 817  5445  01.05.2031      13:00       19:00
# 818  5448  01.05.2032      13:00       19:00
#
#                                                  topic zip_start  \
# 60   "DAUERMAHNWACHE VOR DEM BMJ IN BERLIN. HUNGERS...   HE&#304
# 65   "DAUERMAHNWACHE VOR DEM BMJ IN BERLIN. HUNGERS...   HE&#304
# 72   "DAUERMAHNWACHE VOR DEM BMJ IN BERLIN. HUNGERS...   HE&#304
# 10   "DAUERMAHNWACHE VOR DEM BMJ IN BERLIN. HUNGERS...   HE&#304
# 1    "DAUERMAHNWACHE VOR DEM BMJ IN BERLIN. HUNGERS...   HE&#304
# ...
