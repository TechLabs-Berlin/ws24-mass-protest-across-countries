# %% [markdown]
# ## translate

# %% [markdown]
# lessing it here as csv also available as excel (excel takes less space)

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab_Notebooks/TechLabs/MP
# Out:
# /content/drive/MyDrive/Colab_Notebooks/TechLabs/MP

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100) # Show all columns when looking at dataframe

# %%
pip install googletrans==3.1.0a0

# %%
import googletrans

print(googletrans.LANGUAGES)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'l
# ...

# %%
from googletrans import Translator

translator = Translator()

# %%
result = translator.translate('hallo, ich gehe zum protest ', dest='en', src='de')
if result :
  print(result)
else:
  print('None')
# Out:
# Translated(src=de, dest=en, text=Hello, I'm going to the protest, pronunciation=Hello, I'm going to the protest, extra_data="{'translat...")

# %% [markdown]
# https://stackabuse.com/text-translation-with-google-translate-api-in-python/
#
# with me it always has an error:
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# solved Error with this:
# https://pytutorial.com/python-solve-err-googletrans/
#
# i did not have the newest  version so it was not working with the googletranslte api  together

# %% [markdown]
# ## new working with csv

# %%
df = pd.read_csv("data/protest registrations berlin_zenodo.csv",  on_bad_lines='warn')

# %%
df.head(50)

# %%
df.tail(50)

# %%
df['Topic ']
# Out:
# 0        "Abour Zamani / Familiennachholung aus Afghani...
# 1                                                "Climate"
# 2        "Stoppt die Verfolgung von FALUN DAFA / FALUN ...
# 3        "Kein US-Krieg gegen Venezuela USA Unblock Ven...
# 4        ´ Coronakritische Versammlung Treffpunkt Blank...
#                                ...
# 28073                                  Silvester zum Knast
# 28074    Frieden! Wie seit fast 200 Wochen. Lieben Dank...
# 28075    ... gegen den falschen Standort BER ... (vom 0...
# 28076    Kundgebung gegen die Schließung der Jugendzent...
# 28077    Mahnwache zur Erinnerung an die Opfer des atom...
# Name: Topic , Length: 28078, dtype: object

# %%
pd.set_option('display.max_rows', None)
df['Actual Participants '].value_counts()
# Out:
# 0.0         1659
# 3.0         1381
# 2.0         1321
# 10.0        1222
# 20.0        1218
# 4.0         1094
# 5.0         1052
# 15.0        1045
# 30.0         959
# 50.0         800
# 6.0          678
# 25.0         647
# 40.0         605
# 8.0          603
# 7.0          519
# 100.0        468
# 12.0         417
# 60.0         392
# 35.0         332
# 80.0         316
# 70.0         308
# 150.0        299
# 1.0          287
# 200.0        257
# 9.0          248
# 120.0        216
# 11.0         184
# 250.0        171
# 13.0         165
# 14.0         157
# 18.0         149
# 300.0        139
# 45.0         139
# 16.0         124
# 17.0         111
# 90.0         100
# 350.0         87
# 400.0         81
# 500.0         77
# 55.0          73
# 21.0          70
# 22.0          70
# 65.0          70
# 110.0         69
# 28.0          61
# 130.0         59
# 19.0          58
# 75.0          56
# 26.0          55
# 23.0          55
# 600.0         47
# 180.0         47
# ...

# %%
df.sort_values(['Actual Participants '], ascending=False).head(4000)
# Out:
#        County    City        Date  \
# 26242  Berlin  Berlin  2018-07-28
# 27237  Berlin  Berlin  2018-10-13
# 22097  Berlin  Berlin  2019-09-20
# 5061   Berlin  Berlin  2022-10-22
# 9918   Berlin  Berlin  2021-07-24
# 23290  Berlin  Berlin  2019-11-29
# 23939  Berlin  Berlin  2018-01-20
# 12883  Berlin  Berlin  2020-01-18
# 20577  Berlin  Berlin  2019-06-02
# 19433  Berlin  Berlin  2019-03-29
# 15745  Berlin  Berlin  2020-08-01
# 19209  Berlin  Berlin  2019-03-15
# 15727  Berlin  Berlin  2020-08-01
# 1248   Berlin  Berlin  2022-03-20
# 18470  Berlin  Berlin  2019-01-19
# 2385   Berlin  Berlin  2022-05-29
# 14764  Berlin  Berlin  2020-06-06
# 25440  Berlin  Berlin  2018-05-27
# 24877  Berlin  Berlin  2018-04-14
# 1332   Berlin  Berlin  2022-03-25
# 19335  Berlin  Berlin  2019-03-23
# 20420  Berlin  Berlin  2019-05-24
# 19092  Berlin  Berlin  2019-03-08
# 18960  Berlin  Berlin  2019-02-27
# 19933  Berlin  Berlin  2019-05-01
# 20329  Berlin  Berlin  2019-05-19
# ...

# %%
df.sort_values(['Actual Participants '], ascending=False).tail(10000)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
